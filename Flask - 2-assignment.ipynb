# %%
# Q1. Explain GET and POST methods.

# %%
# The GET method is used to retrieve information from the given server using a given URl.
# Requests using GET only retrieves data and it dose not should have other effect on the data.
# GET requests can be cached
# GET requests remain in the browser history
# Data is visible to everyone in the URL
# GET requests can be bookmarked
# GET requests should never be used when dealing with sensitive data
# GET requests have length restrictions
# GET requests are only used to request data (not modify)

# %%
# POST is used to send data to a server to create/update a resource.
# POST requests are never cached
# POST requests do not remain in the browser history
# Data is not displayed in the URL
# POST requests cannot be bookmarked
# POST requests have no restrictions on data length

# %%
# Q2. Why is request used in Flask?

# %%
# The Hypertext Transfer Protocol (HTTP) is designed to enable communications between clients and servers.
# HTTP works as a request-response protocol between a client and server.
# The request context allows you to obtain data sent from the client such as a web browser so that
# you can appropriately handle generating the response.
# The Request, in Flask, is an object that contains all the data sent from the Client to Server.
# eg. A client (browser) sends an HTTP request to the server; then the server returns a response to the client. 
# The response contains status information about the request and may also contain the requested content.

# %%
# Q3. Why is redirect() used in Flask?

# %%
# The redirect() function allows us to redirect a user to the URL of our choice.

# %%
# Q4. What are templates in Flask? Why is the render_template() function used?

# %%
# Templates are files that contain static data as well as placeholders for dynamic data. 
# A template is rendered with specific data to produce a final document. 
# Flask uses the Jinja template library to render templates.

# %%
# render_template is a Flask function from the flask. templating package. 
# render_template is used to generate output from a template file based on the Jinja2 engine 
# that is found in the application's templates folder.
# we just need to provide the name of the template instead of the entire path to the template.

# %%
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
'''
from flask import Flask, render_template, url_for, request, redirect, jsonify

app = Flask(__name__)

@app.route("/login", methods=['POST'])
def login(): 
    data = request.get_json()
    user_name = data["username"]
    password = data["password"]   
    if user_name == "sudh" and password == "123456":
        return {"status":True, "msg":"Login Successful", "data":[ ]}
    return {"status":False, "msg":"Invalid username/wrong password", "data":[]}
        
if __name__=="__main__":
    app.run(host = '0.0.0.0', debug=True)

'''
# Out:
# '\nfrom flask import Flask, render_template, url_for, request, redirect, jsonify\n\napp = Flask(__name__)\n\n@app.route("/login", methods=[\'POST\'])\ndef login(): \n    data = request.get_json()\n    user_name = data["username"]\n    password = data["password"]   \n    if user_name == "sudh" and password == "123456":\n        return {"status":True, "msg":"Login Successful", "data":[ ]}\n    return {"status":False, "msg":"Invalid username/wrong password", "data":[]}\n        \nif __name__=="__main__":\n    app.run(host = \'0.0.0.0\', debug=True)\n\n'

# %% [markdown]
# ![image.png](attachment:14a8d4a7-3c31-45a5-9862-d1ac15ba9c5e.png)

# %% [markdown]
# ![image.png](attachment:d362ce97-3814-4c4e-aeb3-3ef3917181d1.png)
